# %% [markdown]
# 1. start jupyter service

# %% [raw]
# jupyter notebook

# %% [markdown]
# 2. create a new notebook

# %% [markdown]
# 3. Jupyter notebook shortcuts

# %% [markdown]
# 4. command mode and cell mode
